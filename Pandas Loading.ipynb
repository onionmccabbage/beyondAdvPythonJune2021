# %% [markdown]
# ## Loading External Files

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read external csv into a dataframe
df = pd.read_csv('data_sources/ex1.csv', sep=',') # sep is optional
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
names = ['a','b','c','d','message']
df = pd.read_csv('data_sources/ex2.csv', names=names, index_col='message', header=None)
df
# Out:
#          a   b   c   d
# message
# hello    1   2   3   4
# world    5   6   7   8
# foo      9  10  11  12

# %%
df = pd.read_csv('data_sources/ex4.csv', skiprows=[0,2,3])
df = pd.read_csv('data_sources/ex5.csv', na_values=3.0) # what value should be made into NaN
pd.isnull(df)
df
# Out:
#   something  a   b     c   d message
# 0       one  1   2   NaN   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %% [markdown]
# ## Large Data Sets

# %%
df6 = pd.read_csv('data_sources/ex6.csv') #, nrows=40)
df6.describe()

# %%
df6
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]

# %%
# sometimes it makes sense to 'chunk' our data
f6 = pd.read_csv('data_sources/ex6.csv', nrows=5)
df6.describe()
df6
# we may choose to read a chunk at a time
chunks = pd.read_csv('data_sources/ex6.csv', chunksize=1000)
all = pd.Series([], dtype='float64')
for piece in chunks:
    all = all.add(piece['key'].value_counts(), fill_value=0) # fill missing values
    
all
# Out:
# 0    151.0
# 1    146.0
# 2    152.0
# 3    162.0
# 4    171.0
# 5    157.0
# 6    166.0
# 7    164.0
# 8    162.0
# 9    150.0
# A    320.0
# B    302.0
# C    286.0
# D    320.0
# E    368.0
# F    335.0
# G    308.0
# H    330.0
# I    327.0
# J    337.0
# K    334.0
# L    346.0
# M    338.0
# N    306.0
# O    343.0
# P    324.0
# Q    340.0
# R    318.0
# S    308.0
# T    304.0
# U    326.0
# V    328.0
# W    305.0
# X    364.0
# Y    314.0
# Z    288.0
# dtype: float64

# %% [markdown]
# ## Reading Excel and Writing Data out

# %%
excel = pd.read_excel('data_sources/ex1.xlsx')
excel
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
excel.to_csv('data_sources/output.csv', sep='-')

# %% [markdown]
# ## Working with JSON

# %%
import json
# remember JSON is TEXT (not JavaScript)
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
              {"name": "Katie", "age": 38,
               "pets": ["Sixes", "Stache", "Cisco"]}]
}
"""
type(obj)
r=json.loads(obj)
type(r)
# make a series
s = pd.Series(r)
s.to_json('data_sources/wes.json')

# %%
## Working with API end-points
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
response = requests.get(url)
data = response.json() # [7]['title'] # nb must use [] notation
data
issues = pd.DataFrame(data, columns=['number', 'title', 'labels', 'state'])
# we can make any column into an index
issues
# Out:
#     number                                              title  \
# 0    42102  Indexing MultiIndex with duplicates return Ser...
# 1    42101  BUG: `Styler.hide_columns()` does not hide ind...
# 2    42100    REF: use only inherit_names in CategoricalIndex
# 3    42099  BUG: Adding Series to empty DataFrame can rese...
# 4    42095               CLN: use fused type for lib.has_infs
# 5    42091  REGR: Subclassing `Styler` and addressing `fro...
# 6    42090                   [WIP] BUG: fix `Series.argsort`
# 7    42087  REGR: undocumented astype("category").astype(s...
# 8    42085  BUG: groupby any/all raising with pd.NA object...
# 9    42084                                   PERF/CLN: to_csv
# 10   42078        When change default dtype for empty Series?
# 11   42076          CI: disable auto-cancel for master branch
# 12   42070         BUG: error writing sparse DataFrame to HDF
# 13   42068  BUG: pd.to_datetime(infer_datetime_format=True...
# 14   42066  DOC: How to use storage_option param here to i...
# 15   42064  BUG: rolling std can't handle mixture of (rela...
# 16   42063  BUG: avoid unnecessary casting in CategoricalI...
# 17   42061  Allow passing custom sentinel into MultiIndex....
# 18   42056            BUG: pd.Series.argsort misaligned index
# 19   42055  BUG: IndexError when slicing a series, if a le...
# 20   42054  ENH: Implement skiptrailingspace parameter for...
# 21   42053  BUG: `Styler` subclassing and `from_custom_tem...
# 22   42049  BUG: hash_pandas_object ignores optional argum...
# 23   42044                TYP: Type hints & assert statements
# 24   42031                 PERF: groupsort_indexer contiguity
# 25   42026                       CI: fsspec 2021.6.0 failures
# 26   42021                  BUG: passing str to GroupBy.apply
# 27   42020               Fix module name for _LoadSparseFrame
# 28   42016  BUG: groupby with dropna=False and 'unique' ag...
# 29   42014  BUG: `Styler.apply` consistently manages Serie...
#
#                                                labels state
# 0   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 1   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 2                                                  []  open
# 3   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 4   [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
# 5                                                  []  open
# 6                                                  []  open
# 7   [{'id': 78527356, 'node_id': 'MDU6TGFiZWw3ODUy...  open
# 8   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 9   [{'id': 47229171, 'node_id': 'MDU6TGFiZWw0NzIy...  open
# 10  [{'id': 87485152, 'node_id': 'MDU6TGFiZWw4NzQ4...  open
# 11  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 12  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 13  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 14  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 15  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 16  [{'id': 78527356, 'node_id': 'MDU6TGFiZWw3ODUy...  open
# 17                                                 []  open
# 18  [{'id': 57296398, 'node_id': 'MDU6TGFiZWw1NzI5...  open
# 19  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 20  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 21  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 22  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 23  [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 24  [{'id': 57296398, 'node_id': 'MDU6TGFiZWw1NzI5...  open
# 25  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 26  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 27                                                 []  open
# 28  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 29                                                 []  open
